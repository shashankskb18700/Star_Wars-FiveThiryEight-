# %%
import pandas as pd
import numpy as np

star_wars=pd.read_csv("star_wars.csv",encoding="ISO-8859-1")

# %%
star_wars.head(10)
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
# 5  3.292731e+09                                                Yes
# 6  3.292719e+09                                                Yes
# 7  3.292685e+09                                                Yes
# 8  3.292664e+09                                                Yes
# 9  3.292654e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# ...

# %%
star_wars.columns
# Out:
# Index(['RespondentID',
#        'Have you seen any of the 6 films in the Star Wars franchise?',
#        'Do you consider yourself to be a fan of the Star Wars film franchise?',
#        'Which of the following Star Wars films have you seen? Please select all that apply.',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14',
#        'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Which character shot first?',
# ...

# %%
star_wars=star_wars[star_wars['RespondentID'].notnull()]

# %%
star_wars
# Out:
#       RespondentID  \
# 1     3.292880e+09
# 2     3.292880e+09
# 3     3.292765e+09
# 4     3.292763e+09
# 5     3.292731e+09
# 6     3.292719e+09
# 7     3.292685e+09
# 8     3.292664e+09
# 9     3.292654e+09
# 10    3.292640e+09
# 11    3.292638e+09
# 12    3.292635e+09
# 13    3.292609e+09
# 14    3.292597e+09
# 15    3.292587e+09
# 16    3.292583e+09
# 17    3.292581e+09
# 18    3.292573e+09
# 19    3.292565e+09
# 20    3.292562e+09
# 21    3.292522e+09
# 22    3.292521e+09
# 23    3.292512e+09
# 24    3.292483e+09
# 25    3.292465e+09
# 26    3.292448e+09
# 27    3.292420e+09
# 28    3.292384e+09
# 29    3.292380e+09
# 30    3.292377e+09
# ...            ...
# 1157  3.288426e+09
# 1158  3.288423e+09
# 1159  3.288423e+09
# 1160  3.288422e+09
# 1161  3.288421e+09
# 1162  3.288418e+09
# 1163  3.288418e+09
# 1164  3.288417e+09
# 1165  3.288415e+09
# 1166  3.288414e+09
# 1167  3.288413e+09
# 1168  3.288410e+09
# 1169  3.288410e+09
# 1170  3.288409e+09
# 1171  3.288403e+09
# ...

# %% [markdown]
# readed the five thirty eight data set into data frame and assigned to it as a variable name star_wars

# %%
d={"Yes":True,"No":False}
star_wars['Have you seen any of the 6 films in the Star Wars franchise?']=star_wars['Have you seen any of the 6 films in the Star Wars franchise?'].map(d) 
star_wars['Do you consider yourself to be a fan of the Star Wars film franchise?']=star_wars['Do you consider yourself to be a fan of the Star Wars film franchise?'].map(d)

# %%
star_wars
# Out:
#       RespondentID  \
# 1     3.292880e+09
# 2     3.292880e+09
# 3     3.292765e+09
# 4     3.292763e+09
# 5     3.292731e+09
# 6     3.292719e+09
# 7     3.292685e+09
# 8     3.292664e+09
# 9     3.292654e+09
# 10    3.292640e+09
# 11    3.292638e+09
# 12    3.292635e+09
# 13    3.292609e+09
# 14    3.292597e+09
# 15    3.292587e+09
# 16    3.292583e+09
# 17    3.292581e+09
# 18    3.292573e+09
# 19    3.292565e+09
# 20    3.292562e+09
# 21    3.292522e+09
# 22    3.292521e+09
# 23    3.292512e+09
# 24    3.292483e+09
# 25    3.292465e+09
# 26    3.292448e+09
# 27    3.292420e+09
# 28    3.292384e+09
# 29    3.292380e+09
# 30    3.292377e+09
# ...            ...
# 1157  3.288426e+09
# 1158  3.288423e+09
# 1159  3.288423e+09
# 1160  3.288422e+09
# 1161  3.288421e+09
# 1162  3.288418e+09
# 1163  3.288418e+09
# 1164  3.288417e+09
# 1165  3.288415e+09
# 1166  3.288414e+09
# 1167  3.288413e+09
# 1168  3.288410e+09
# 1169  3.288410e+09
# 1170  3.288409e+09
# 1171  3.288403e+09
# ...

# %%
# d={"Star Wars: Episode I The Phantom Menace":True,
#   "Star Wars: Episode II Attack of the Clones":True,
#   "Star Wars: Episode III Revenge of the Sith":True,
#   "Star Wars: Episode IV A New Hope":True,
#   "star Wars: Episode V The Empire Strikes Back":True,
#   "Star Wars: Episode VI Return of the Jedi":True,
#   np.nan:False}
movie_mapping = {
    "Star Wars: Episode I  The Phantom Menace": True,
    np.nan: False,
    "Star Wars: Episode II  Attack of the Clones": True,
    "Star Wars: Episode III  Revenge of the Sith": True,
    "Star Wars: Episode IV  A New Hope": True,
    "Star Wars: Episode V The Empire Strikes Back": True,
    "Star Wars: Episode VI Return of the Jedi": True
}

# %%
for col in star_wars.columns[3:9]:
    star_wars[col]=star_wars[col].map(movie_mapping)

# %%
star_wars
# Out:
#       RespondentID  \
# 1     3.292880e+09
# 2     3.292880e+09
# 3     3.292765e+09
# 4     3.292763e+09
# 5     3.292731e+09
# 6     3.292719e+09
# 7     3.292685e+09
# 8     3.292664e+09
# 9     3.292654e+09
# 10    3.292640e+09
# 11    3.292638e+09
# 12    3.292635e+09
# 13    3.292609e+09
# 14    3.292597e+09
# 15    3.292587e+09
# 16    3.292583e+09
# 17    3.292581e+09
# 18    3.292573e+09
# 19    3.292565e+09
# 20    3.292562e+09
# 21    3.292522e+09
# 22    3.292521e+09
# 23    3.292512e+09
# 24    3.292483e+09
# 25    3.292465e+09
# 26    3.292448e+09
# 27    3.292420e+09
# 28    3.292384e+09
# 29    3.292380e+09
# 30    3.292377e+09
# ...            ...
# 1157  3.288426e+09
# 1158  3.288423e+09
# 1159  3.288423e+09
# 1160  3.288422e+09
# 1161  3.288421e+09
# 1162  3.288418e+09
# 1163  3.288418e+09
# 1164  3.288417e+09
# 1165  3.288415e+09
# 1166  3.288414e+09
# 1167  3.288413e+09
# 1168  3.288410e+09
# 1169  3.288410e+09
# 1170  3.288409e+09
# 1171  3.288403e+09
# ...

# %%
column_nam=star_wars.columns[3:9]

# %%
dic={"Which of the following Star Wars films have you seen? Please select all that apply.":'seen_1',
    "Unnamed: 4":'seen_2',
    "Unnamed: 5":'seen_3',
    "Unnamed: 6":'seen_4',
    "Unnamed: 7":'seen_5',
    "Unnamed: 8":'seen_6'
    }

# %%
star_wars=star_wars.rename(columns={"Which of the following Star Wars films have you seen? Please select all that apply.":'seen_1',
    "Unnamed: 4":'seen_2',
    "Unnamed: 5":'seen_3',
    "Unnamed: 6":'seen_4',
    "Unnamed: 7":'seen_5',
    "Unnamed: 8":'seen_6'
    }

)

# %%
for t in star_wars.columns[9:15]:
    star_wars[t]=star_wars[t].astype('float')

# %%
type(star_wars['Unnamed: 10'])
# Out:
# pandas.core.series.Series

# %%
star_wars=star_wars.rename(columns={
       
       'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.':"ranking_1",
    
       'Unnamed: 10':'ranking_2',
       
       'Unnamed: 11':'ranking_3',
       'Unnamed: 12':'ranking_4',
       'Unnamed: 13':'ranking_5',
       'Unnamed: 14':'ranking_6'
       
      })

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
m_stw=star_wars[['ranking_1','ranking_2','ranking_3','ranking_4','ranking_5','ranking_6']].mean()

# %%
m_stw.plot.bar()

# %% [markdown]
# some columns are named as unnamed so i rename with a better name and like ranking and seen
# ###### then i converted colums(9:15) to  float
# and then calculated mean of every ranking column and then plotted the graph
#
# ###### now it is clear that  ranking_5 (movie- Star wars -3 Revenge of sith) is most l liked move ,i think ,it is repondent like this move so much because It was supposed to be the last entry in George Lucas's epic story

# %%
mvy_w=star_wars[['seen_1','seen_2','seen_3','seen_4','seen_5','seen_6']].sum()

# %%
mvy_w.plot.bar()

# %% [markdown]
# as we have seen that ranking_5(Star war:Revenge of sith) is most rated moves and thats why it is also most watched star war film
# ##### seen 5 has hightest value among all the seens ,this thing shows that Star wars :Revenge of sith is the best film ever produced by star wars franchise

# %%
f_stwf=star_wars[star_wars['Do you consider yourself to be a fan of the Star Wars film franchise?']==True]

# %%
stf=f_stwf[['ranking_1','ranking_2','ranking_3','ranking_4','ranking_5','ranking_6']].mean()

# %%
stf.plot.bar()

# %%
stf_s=f_stwf[['seen_1','seen_2','seen_3','seen_4','seen_5','seen_6']]

# %%
stf.plot.bar()

# %% [markdown]
# splited data frame into two parts on the basis of fans of star wars franchise and star wars treak
# #### f_stwf is for  fans of star wars franchise
#
# then created two new series
# #### stf , it is  according to column of ranking for star war franchise
# #### stf_s ,it is according to column seeen for star war franchise

# %%
f_stwt
# Out:
# 0

# %%
stt=f_stwt[['ranking_1','ranking_2','ranking_3','ranking_4','ranking_5','ranking_6']]
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-190-55859e5ee120> in <module>()
# ----> 1 stt=f_stwt[['ranking_1','ranking_2','ranking_3','ranking_4','ranking_5','ranking_6']]
#
# TypeError: 'int' object is not subscriptable

# %%
def yN(row):
    if row=='Yes':
        return True
    elif row=='No':
        return False



star_wars['a']=star_wars['Do you consider yourself to be a fan of the Star Trek franchise?'].map(yN)

# %%
star_wars['Do you consider yourself to be a fan of the Star Trek franchise?']=star_wars['a']

# %%
f_stwt=star_wars[star_wars['Do you consider yourself to be a fan of the Star Trek franchise?']==True]

# %%
sttr=f_stwt[['ranking_1','ranking_2','ranking_3','ranking_4','ranking_5','ranking_6']].mean()

# %%
sttr.plot.bar()

# %%
stts=f_stwt[['seen_1','seen_2','seen_3','seen_4','seen_5','seen_6']].sum()

# %%
stts.plot.bar()

# %% [markdown]
# ##### f_stwt is a dataframe that i filterd form star war according to colum '''Do you consider yourself to be a fan of the Star Trek franchise?'''
# bcz actually this data frame is persent in form of yes and no so we have to convert it in form of boolen(true or false) ,otherwise we are not able  to apply  sum functon
#
#
# #####  even after spliiting ,pattern didn't changed that much ,still ranking_5(star_wars:revenge of sith ) is the most rated and most watched movie in both of these datasets
